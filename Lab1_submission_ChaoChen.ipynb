# %% [markdown]
# ---
# ## Deliverables (Submission Checklist)
#
# Submit a ZIP (or repo link) containing:
#
# `Please checkout this repo link - `[https://github.com/ouut/AIG240_Robotics](https://github.com/ouut/AIG240_Robotics)
#
# 1. **Evidence**
#    - Screenshots (or short screen recording) showing:
#      - `turtlesim_node` running
#          - ![image.png](attachment:81903d09-cf76-475d-a158-5f234dfce2f2.png)
#      - rqt service calls (`/spawn`, `/turtle3/set_pen`)
#          - ![image.png](attachment:45b57914-8338-4b94-850e-eafbddd8640d.png)
#      - turtle1/turtle2/turtle3 visible
#          - ![image.png](attachment:3af3899d-c1e8-47e4-958e-6cd444e950f0.png)
#      - turtle3 drawing in green
#          - ![image.png](attachment:02c598d5-118e-4948-9967-62f9759f94d6.png)
#
# 2. **Your ROS 2 packages**
#    - `lab1_turtle_py` (with `square_driver.py` and updated `setup.py`)
#        - ![image.png](attachment:51712a5d-92c8-4910-9f6c-30a876f7487a.png)
#    - `lab1_turtle_cpp` (with `square_driver.cpp` and updated `CMakeLists.txt`)
#        - ![image.png](attachment:2d995627-71dd-4221-90b2-7942ea2952a9.png)
#
# 3. **Short answers (5–8 sentences each)**
#    - Difference between a **topic** and a **service** in ROS 2
#        - topic relates to a design pattern in software - publish/subscribe
#        - publish node send a message to a topic and all subscribe nodes will get the message
#        - this design decouple the system,allowing nodes to be added easily without affecting others.
#        - A service relates to a remote procedure call (RPC): one node exposes a function (the service server), and another node (the client) can call this API directly to get a synchronous return.
#    - What remapping changed in your system
#        - remapping is used to map an input or output from one node to another. It means developers do not need to change the code to alter the message workflow, making the system easy to use and highly reusable.
#    - Why time-based control is **open loop**, and one way to close the loop later
#        - Open Loop means system excute the a command without feedback from the environment
#        - closed-loop means that to achieve a final goal, the system needs to consider the effects from the environment and update its commands to align with the final goal.
#        - For example, when a robot executes a command to run at 2m/s, but the engine power is insufficient, the real speed is only 1.5m/s. The sensors feedback the actual speed to the system, which then increases the power to ensure the real speed reaches and maintains 2m/s.
